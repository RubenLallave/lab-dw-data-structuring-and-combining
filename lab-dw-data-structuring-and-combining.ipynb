# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv")
df2 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")
df3 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")

display(df.head(3))
display(df2.head(3))
display(df3.head(3))
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value   Income  \
# 0  RB50392  Washington    NaN    Master                     NaN      0.0
# 1  QZ44356     Arizona      F  Bachelor              697953.59%      0.0
# 2  AI49188      Nevada      F  Bachelor             1288743.17%  48767.0
#
#    Monthly Premium Auto Number of Open Complaints    Policy Type  \
# 0                1000.0                    1/0/00  Personal Auto
# 1                  94.0                    1/0/00  Personal Auto
# 2                 108.0                    1/0/00  Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# ...

# %%
#One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset

df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")
df = df.rename({"st": "state"}, axis=1)
display(df.head(0))

df2.columns = df2.columns.str.lower()
df2.columns = df2.columns.str.replace(" ", "_")
df2 = df2.rename({"st": "state"}, axis=1)
display(df2.head(0))

df3.columns = df3.columns.str.lower()
df3.columns = df3.columns.str.replace(" ", "_")
display(df3.head(0))
# Out:
# Empty DataFrame
# Columns: [customer, state, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, policy_type, vehicle_class, total_claim_amount]
# Index: []
# Empty DataFrame
# Columns: [customer, state, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, total_claim_amount, policy_type, vehicle_class]
# Index: []
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, education, gender, income, monthly_premium_auto, number_of_open_complaints, policy_type, total_claim_amount, vehicle_class]
# Index: []

# %%
df_new = pd.concat([df, df2, df3], axis=0, join="outer")
df_new
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df_new["gender"].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
df_new["gender"] = df_new["gender"].str.replace("Femal", "F")
df_new["gender"] = df_new["gender"].str.replace("female", "F")
df_new["gender"] = df_new["gender"].str.replace("Male", "M")

df_new["gender"].unique()
# Out:
# array([nan, 'F', 'M'], dtype=object)

# %%
df_new["state"].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
df_new["state"] = df_new["state"].str.replace("AZ", "Arizona")
df_new["state"] = df_new["state"].str.replace("WA", "Washington")
df_new["state"].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        nan], dtype=object)

# %%
df_new["education"].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College',
#        'Bachelors', 'Doctor', nan], dtype=object)

# %%
df_new["education"] = df_new["education"].str.replace("Bachelors", "Bachelor")
df_new["education"].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College', 'Doctor',
#        nan], dtype=object)

# %%
df_new["customer_lifetime_value"] = df_new["customer_lifetime_value"].str.replace("%","")
df_new
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
df_new.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
df_new["customer_lifetime_value"] = df_new["customer_lifetime_value"].astype(float)
df_new.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
df_new["number_of_open_complaints"].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan, 0,
#        2, 3, 1, 5, 4], dtype=object)

# %%
df_new["number_of_open_complaints"] = df_new["number_of_open_complaints"].str.split("/")
df_new['number_of_open_complaints'] = df_new['number_of_open_complaints'].apply(lambda x: x[1] if len(x) > 1 else None)
df_new.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 df_new["number_of_open_complaints"] = df_new["number_of_open_complaints"].str.split("/")
# ----> 2 df_new['number_of_open_complaints'] = df_new['number_of_open_complaints'].apply(lambda x: x[1] if len(x) > 1 else None)
#       3 df_new.head()
#
# File c:\Users\ruben\anaconda3\Anaconda\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
# ...

# %%
print(df_new.isna().sum())
# Out:
# customer                      2937
# state                         2937
# gender                        3059
# education                     2937
# customer_lifetime_value      10014
# income                        2937
# monthly_premium_auto          2937
# number_of_open_complaints    10007
# policy_type                   2937
# vehicle_class                 2937
# total_claim_amount            2937
# dtype: int64

# %%
df_new["gender"].fillna("undifined", inplace=True)
# Out:
# C:\Users\ruben\AppData\Local\Temp\ipykernel_3328\3559216234.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new["gender"].fillna("undifined", inplace=True)

# %%
df_new.dropna(inplace=True)
df_new
# Out:
#     customer       state gender             education  \
# 1    QZ44356     Arizona      F              Bachelor
# 2    AI49188      Nevada      F              Bachelor
# 3    WW63253  California      M              Bachelor
# 4    GA49547  Washington      M  High School or Below
# 5    OC83172      Oregon      F              Bachelor
# ..       ...         ...    ...                   ...
# 991  HV85198     Arizona      M                Master
# 992  BS91566     Arizona      F               College
# 993  IL40123      Nevada      F               College
# 994  MY32149  California      F                Master
# 995  SA91515  California      M              Bachelor
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# 3                  764586.18      0.0                 106.0
# 4                  536307.65  36357.0                  68.0
# ...

# %%
df_new['customer'].duplicated().sum()
# Out:
# 3

# %%
df_new.drop_duplicates(subset=['customer'], keep= 'last', inplace=True)
df_new.reset_index(drop=True, inplace=True)
df_new['customer'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
df_structuring = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv")
df_structuring
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
#You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. 
# Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).

df_structuring.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='object')

# %%
df_structuring["monthly_premium_auto"].unique()
# Out:
# array([ 61,  64, 100,  97, 117,  63, 154,  85, 127,  62,  99,  69, 116,
#        114,  66,  73,  94, 104, 189,  74, 121, 110, 111,  72, 115, 159,
#        101,  65,  82,  71, 126,  68, 199,  96,  67, 125, 249, 105,  92,
#         78,  77,  79, 223, 242,  70, 102, 109, 107, 119, 194, 113, 106,
#        247,  80,  86,  81,  83, 122, 253, 196, 132, 139,  84, 130,  93,
#        103, 112, 222, 118,  88, 182, 283,  90, 128,  89, 235, 190,  76,
#         87, 133, 153, 129,  98, 148, 123,  91, 211, 131, 108, 187, 214,
#        181, 173, 252,  95, 124, 137, 145, 188, 143, 198, 138, 245, 195,
#        186, 170, 136, 161, 157, 141, 205, 271, 192, 142, 140, 134, 240,
#        185, 244, 210, 184, 202, 296, 213, 273, 219, 135, 169, 155, 225,
#        266, 215, 197, 256, 212, 158, 180, 166, 168, 183, 162, 191, 179,
#        150, 146, 276, 165, 239, 237, 193, 229, 274, 207, 295, 208, 172,
#        217, 206, 201, 171, 152, 156, 174, 238, 167, 151, 144, 163, 287,
# ...

# %%
df_structuring_pivot_table = df_structuring.pivot_table(index='sales_channel', values='monthly_premium_auto', aggfunc='sum')
df_structuring_pivot_table
# Out:
#                monthly_premium_auto
# sales_channel
# Agent                        386335
# Branch                       280953
# Call Center                  197970
# Web                          151511

# %%
#Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.
round(df_structuring_pivot_table["monthly_premium_auto"], 2)
# Out:
# sales_channel
# Agent          386335
# Branch         280953
# Call Center    197970
# Web            151511
# Name: monthly_premium_auto, dtype: int64

# %%
#Create a pivot table that shows the average customer lifetime value per gender and education level.
df_Customer_Lifetime_Value=df_structuring.pivot_table(index= "gender",columns= "education",values= "customer_lifetime_value",aggfunc= "mean",)
df_Customer_Lifetime_Value
# Out:
# education     Bachelor      College       Doctor  High School or Below  \
# gender
# F          7874.269478  7748.823325  7328.508916           8675.220201
# M          7703.601675  8052.459288  7415.333638           8149.687783
#
# education       Master
# gender
# F          8157.053154
# M          8168.832659

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
